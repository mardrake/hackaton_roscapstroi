# %% [markdown]
# ### Загрузка данных

# %%
# !pip install pymorphy2
# !pip install gradio
# Out:
# Requirement already satisfied: pymorphy2 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (0.8)
# Requirement already satisfied: dawg-python>=0.7 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts<3.0,>=2.4 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pymorphy2) (2.4.393442.3710985)
# Requirement already satisfied: docopt>=0.6 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pymorphy2) (0.6.2)
# Requirement already satisfied: gradio in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (3.23.0)
# Requirement already satisfied: aiofiles in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (22.1.0)
# Requirement already satisfied: aiohttp in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (3.8.4)
# Requirement already satisfied: altair>=4.2.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (5.0.0)
# Requirement already satisfied: fastapi in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (0.77.1)
# Requirement already satisfied: ffmpy in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (0.3.0)
# Requirement already satisfied: fsspec in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (2023.5.0)
# Requirement already satisfied: httpx in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (0.24.1)
# Requirement already satisfied: huggingface-hub in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (0.14.1)
# Requirement already satisfied: jinja2 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (2.2.0)
# Requirement already satisfied: markupsafe in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (2.1.2)
# Requirement already satisfied: matplotlib in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (3.7.1)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (0.3.3)
# Requirement already satisfied: numpy in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (1.23.5)
# Requirement already satisfied: orjson in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (3.8.12)
# Requirement already satisfied: pandas in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (1.5.3)
# Requirement already satisfied: pillow in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (9.5.0)
# Requirement already satisfied: pydantic in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (1.10.7)
# Requirement already satisfied: pydub in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: pyyaml in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (6.0)
# Requirement already satisfied: requests in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (2.29.0)
# Requirement already satisfied: semantic-version in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: typing-extensions in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (4.5.0)
# Requirement already satisfied: uvicorn in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (0.18.3)
# Requirement already satisfied: websockets>=10.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from altair>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from altair>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: filelock in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from huggingface-hub->gradio) (3.9.1)
# Requirement already satisfied: tqdm>=4.42.1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from huggingface-hub->gradio) (4.64.1)
# Requirement already satisfied: packaging>=20.9 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from huggingface-hub->gradio) (23.1)
# Requirement already satisfied: mdurl~=0.1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pandas->gradio) (2023.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->gradio) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->gradio) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->gradio) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->gradio) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->gradio) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->gradio) (1.3.1)
# Requirement already satisfied: starlette==0.19.1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from fastapi->gradio) (0.19.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from starlette==0.19.1->fastapi->gradio) (3.6.2)
# Requirement already satisfied: certifi in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from httpx->gradio) (2022.12.7)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from httpx->gradio) (0.17.1)
# Requirement already satisfied: idna in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from httpx->gradio) (3.4)
# Requirement already satisfied: sniffio in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from matplotlib->gradio) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from matplotlib->gradio) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from matplotlib->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from matplotlib->gradio) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from matplotlib->gradio) (5.12.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests->gradio) (1.26.15)
# Requirement already satisfied: click>=7.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from uvicorn->gradio) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from uvicorn->gradio) (0.14.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->gradio) (3.15.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.19.3)
# Requirement already satisfied: uc-micro-py in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio) (1.0.2)
# Requirement already satisfied: six>=1.5 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->gradio) (1.16.0)

# %%
# !pip install natasha
# !pip install catboost
# Out:
# Requirement already satisfied: natasha in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (1.5.0)
# Requirement already satisfied: pymorphy2 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from natasha) (0.8)
# Requirement already satisfied: razdel>=0.5.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from natasha) (0.5.0)
# Requirement already satisfied: navec>=0.9.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from natasha) (0.10.0)
# Requirement already satisfied: slovnet>=0.6.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from natasha) (0.6.0)
# Requirement already satisfied: yargy>=0.14.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from natasha) (0.15.1)
# Requirement already satisfied: ipymarkup>=0.8.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from natasha) (0.9.0)
# Requirement already satisfied: intervaltree>=3 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from ipymarkup>=0.8.0->natasha) (3.1.0)
# Requirement already satisfied: numpy in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from navec>=0.9.0->natasha) (1.23.5)
# Requirement already satisfied: dawg-python>=0.7 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pymorphy2->natasha) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts<3.0,>=2.4 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pymorphy2->natasha) (2.4.393442.3710985)
# Requirement already satisfied: docopt>=0.6 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pymorphy2->natasha) (0.6.2)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from intervaltree>=3->ipymarkup>=0.8.0->natasha) (2.4.0)
# Requirement already satisfied: catboost in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (1.2)
# Requirement already satisfied: graphviz in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from catboost) (1.9.3)
# Requirement already satisfied: plotly in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from matplotlib->catboost) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from matplotlib->catboost) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from matplotlib->catboost) (5.12.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from plotly->catboost) (8.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /home/mario/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.15.0)

# %%
import pandas as pd
import numpy as np
from natasha import Segmenter
import pickle
import re
import string
import nltk
import pymorphy2
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import gradio as gr

# %%
dff = pd.read_csv('/home/user/Загрузки/train_dataset_Минстрой(1)/df1.csv', index_col=0)
dff.head()
# Out:
#         id name(название)          responsibilities(Должностные обязанности)  \
# 0  9495846     Арматурщик  Работа на строительных площадках. Очистных соо...
# 1  9495850     Арматурщик  Гнутье арматурной стали на механических станка...
# 2  9495851     Арматурщик                                    Вязка арматуры.
# 3        2     Арматурщик  Выполнение работ по гнутью и резке арматурной ...
# 4  9388857     Арматурщик  Вахта в город .Москва. Обязанности: армировани...
#
#                requirements(Требования к соискателю)  \
# 0                                                ***
# 1                                                ***
# 2                                                ***
# 3  Выполнение работ по гнутью и резке арматурной ...
# 4  опыт в строительстве приветствуется; работа в ...
#
#                                       terms(Условия)  \
# 0                                                ***
# 1                                                ***
# 2                                                ***
# 3                                                ***
# 4  продолжительность вахты 60/30 (продление вахты...
#
#                                     responsibilities
# 0  Работа на строительных площадках. Очистных соо...
# 1  Гнутье арматурной стали на механических станка...
# 2                                    Вязка арматуры.
# 3   .Выполнение работ по сборке и вязке арматурны...
# 4  Вахта в город .Москва. Обязанности: армировани...

# %%
dff.rename(columns = {'name(название)': 'Название', 'responsibilities(Должностные обязанности)':'Описание', 'requirements(Требования к соискателю)':'Требования', 'terms(Условия)': 'Условия', 'responsibilities': 'Обязанности'}, inplace = True )

# %%
dff.head()
# Out:
#         id    Название                                           Описание  \
# 0  9495846  Арматурщик  Работа на строительных площадках. Очистных соо...
# 1  9495850  Арматурщик  Гнутье арматурной стали на механических станка...
# 2  9495851  Арматурщик                                    Вязка арматуры.
# 3        2  Арматурщик  Выполнение работ по гнутью и резке арматурной ...
# 4  9388857  Арматурщик  Вахта в город .Москва. Обязанности: армировани...
#
#                                           Требования  \
# 0                                                ***
# 1                                                ***
# 2                                                ***
# 3  Выполнение работ по гнутью и резке арматурной ...
# 4  опыт в строительстве приветствуется; работа в ...
#
#                                              Условия  \
# 0                                                ***
# 1                                                ***
# 2                                                ***
# 3                                                ***
# 4  продолжительность вахты 60/30 (продление вахты...
#
#                                          Обязанности
# 0  Работа на строительных площадках. Очистных соо...
# 1  Гнутье арматурной стали на механических станка...
# 2                                    Вязка арматуры.
# 3   .Выполнение работ по сборке и вязке арматурны...
# 4  Вахта в город .Москва. Обязанности: армировани...

# %% [markdown]
# ### Обработка данных для загрузки в модель

# %%
df_new = dff.copy()

# %%
# Разбиваем на предложения
segmenter = Segmenter()
def sentenize_text(text):
  sentences = [s.text for s in segmenter.sentenize(text)]
  return sentences

# %%
# Создание тренировочного датасета с метками классов
def split_to_sent(df, col_list):
    df_train = pd.DataFrame()
    for i, col in enumerate(col_list):
        df_splited = pd.DataFrame()
        df_splited['param'] = df[col].apply(sentenize_text)
        df_splited = df_splited.explode('param')
        df_splited['class'] = col
        print(len(df_splited))
        df_train = pd.concat([df_train, df_splited], ignore_index=False)
        df_train = df_train.loc[df_train['param'] != '***']
    return df_train

# %%
df_train = split_to_sent(df_new, df_new.columns[3:6].tolist())
# Out:
# 1559
# 2857
# 3503

# %%
# Смотрим дисбаланс классов
df_train['class'].value_counts()
# Out:
# Обязанности    3500
# Условия        2760
# Требования     1388
# Name: class, dtype: int64

# %%
# Удаление дубликатов строк
df_train.drop_duplicates(subset='param', inplace=True)
df_train['class'].value_counts()
# Out:
# Обязанности    2214
# Условия        1867
# Требования     1051
# Name: class, dtype: int64

# %%
df_train.head()
# Out:
#                                                 param       class
# 3   Выполнение работ по гнутью и резке арматурной ...  Требования
# 4   опыт в строительстве приветствуется; работа в ...  Требования
# 5   Опыт работы от 1 года , наличие удостоверения ...  Требования
# 6   опыт в строительстве приветствуется -работа в ...  Требования
# 11  Понимание работы в бригаде · .Дисциплинированн...  Требования

# %%
df_train.reset_index(inplace=True, drop=True)
df_train.head()
# Out:
#                                                param       class
# 0  Выполнение работ по гнутью и резке арматурной ...  Требования
# 1  опыт в строительстве приветствуется; работа в ...  Требования
# 2  Опыт работы от 1 года , наличие удостоверения ...  Требования
# 3  опыт в строительстве приветствуется -работа в ...  Требования
# 4  Понимание работы в бригаде · .Дисциплинированн...  Требования

# %%
# Сохранение датасета
df_train.to_parquet('/home/user/Загрузки/train_dataset_Минстрой(1)/df_train.parquet.gzip', compression='gzip')

# %%
raw_data = df_train.copy()

# %% [markdown]
# ### Убираем стоп слова и делаем лемматизацию

# %%
spec_chars = string.punctuation + '\n\xa0«»\t—…' # пунктуация
stop_words = stopwords.words('russian') # стоп-слова
morph = pymorphy2.MorphAnalyzer() # лемматизатор
def clean_text(text):
    text = re.sub(r'\s+', ' ', text, flags=re.I)  # удаление лишних пробелов
    text = text.lower()  # перевод в нижний регистр
    text = "".join([ch for ch in text if ch not in spec_chars]) #удаление пунктуации
    words = nltk.word_tokenize(text) # токенизация

    # удаление стоп-слов и лемматизация
    cleaned_words = [morph.parse(w)[0].normal_form for w in words if not w in stop_words and len(w)>1]
    return ' '.join(cleaned_words)

raw_data['clean_text'] = raw_data.param.apply(clean_text)

# %% [markdown]
# ### Делим на тренировочные и тестовые данные

# %%
from sklearn.model_selection import train_test_split
X = raw_data ['clean_text']
y = raw_data ['class']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 42, test_size=0.2)

# %% [markdown]
# ### Подготавливаем и обучаем модель на данных

# %%
from catboost import CatBoostClassifier, Pool
def fit_model(train_pool, test_pool, **kwargs):
    model = CatBoostClassifier(task_type='GPU', iterations = 10000,
                               random_seed=43,
                               leaf_estimation_method='Newton',
                               loss_function='MultiClass',
                               use_best_model=True,
                               eval_metric='TotalF1',
                               od_type='Iter',
                               od_wait=500,
                               **kwargs)

    return model.fit(train_pool, eval_set=test_pool,
                     verbose=100, plot=True,
                     use_best_model=True)

# %%
train_pool = Pool(data=X_train.to_frame(), label=y_train, text_features=['clean_text',], feature_names=['clean_text'])
valid_pool = Pool(data=X_test.to_frame(), label=y_test, text_features=['clean_text',], feature_names=['clean_text'])

# %%
model = fit_model(train_pool, valid_pool, learning_rate=0.1, depth=12, bagging_temperature=0.7, random_strength=0.7,
                  dictionaries = [{
                      'dictionary_id':'Word',
                      'max_dictionary_size': '50000'
                  }],
                 feature_calcers = ['BoW:top_tokens_count=10000'])
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.6735543	test: 0.6646235	best: 0.6646235 (0)	total: 121ms	remaining: 20m 6s
# 100:	learn: 0.8032948	test: 0.7689309	best: 0.7708161 (96)	total: 8.84s	remaining: 14m 26s
# 200:	learn: 0.8298805	test: 0.7727611	best: 0.7729642 (143)	total: 16.8s	remaining: 13m 40s
# 300:	learn: 0.8470377	test: 0.7766982	best: 0.7775004 (249)	total: 24.5s	remaining: 13m 10s
# 400:	learn: 0.8593367	test: 0.7811780	best: 0.7814043 (333)	total: 32.3s	remaining: 12m 53s
# 500:	learn: 0.8701314	test: 0.7828734	best: 0.7830680 (464)	total: 40.1s	remaining: 12m 41s
# 600:	learn: 0.8802262	test: 0.7846434	best: 0.7867225 (509)	total: 48.1s	remaining: 12m 32s
# 700:	learn: 0.8882418	test: 0.7895283	best: 0.7895283 (700)	total: 56s	remaining: 12m 22s
# 800:	learn: 0.8955407	test: 0.7875742	best: 0.7895283 (700)	total: 1m 3s	remaining: 12m 13s
# 900:	learn: 0.9036298	test: 0.7855461	best: 0.7912740 (883)	total: 1m 11s	remaining: 12m 5s
# 1000:	learn: 0.9107652	test: 0.7844363	best: 0.7912740 (883)	total: 1m 19s	remaining: 11m 56s
# 1100:	learn: 0.9189308	test: 0.7857145	best: 0.7912740 (883)	total: 1m 27s	remaining: 11m 49s
# 1200:	learn: 0.9260310	test: 0.7856608	best: 0.7912740 (883)	total: 1m 35s	remaining: 11m 41s
# 1300:	learn: 0.9307040	test: 0.7867510	best: 0.7912740 (883)	total: 1m 43s	remaining: 11m 34s
# bestTest = 0.7912739971
# bestIteration = 883
# Shrink model to first 884 iterations.

# %%
model = fit_model(train_pool, valid_pool, learning_rate=0.1, depth=12, bagging_temperature=0.7, random_strength=0.7,
                  dictionaries = [{
                      'dictionary_id':'Word',
                      'max_dictionary_size': '50000'
                  }],
                 feature_calcers = ['BoW:top_tokens_count=10000'])
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.7085034	test: 0.7028262	best: 0.7028262 (0)	total: 151ms	remaining: 25m 9s
# 100:	learn: 0.8872939	test: 0.8838090	best: 0.8838090 (100)	total: 8.89s	remaining: 14m 31s
# 200:	learn: 0.9063642	test: 0.9007602	best: 0.9007602 (200)	total: 17.1s	remaining: 13m 54s
# 300:	learn: 0.9158892	test: 0.9102773	best: 0.9102773 (300)	total: 25.2s	remaining: 13m 31s
# 400:	learn: 0.9206701	test: 0.9134416	best: 0.9134416 (397)	total: 33.3s	remaining: 13m 18s
# 500:	learn: 0.9238251	test: 0.9152720	best: 0.9153718 (485)	total: 41.6s	remaining: 13m 8s
# 600:	learn: 0.9266442	test: 0.9169952	best: 0.9170941 (598)	total: 48.7s	remaining: 12m 40s
# 700:	learn: 0.9285106	test: 0.9181433	best: 0.9181443 (692)	total: 59.5s	remaining: 13m 8s
# 800:	learn: 0.9303489	test: 0.9198695	best: 0.9198695 (798)	total: 1m 7s	remaining: 12m 59s
# 900:	learn: 0.9317102	test: 0.9213077	best: 0.9213077 (893)	total: 1m 14s	remaining: 12m 37s
# 1000:	learn: 0.9331208	test: 0.9220766	best: 0.9220766 (996)	total: 1m 23s	remaining: 12m 30s
# 1100:	learn: 0.9341257	test: 0.9232258	best: 0.9232258 (1100)	total: 1m 32s	remaining: 12m 24s
# 1200:	learn: 0.9353445	test: 0.9236084	best: 0.9237031 (1189)	total: 1m 39s	remaining: 12m 8s
# 1300:	learn: 0.9367518	test: 0.9241818	best: 0.9241829 (1239)	total: 1m 48s	remaining: 12m 2s
# 1400:	learn: 0.9375873	test: 0.9253263	best: 0.9253263 (1380)	total: 1m 56s	remaining: 11m 52s
# 1500:	learn: 0.9387089	test: 0.9257972	best: 0.9258000 (1490)	total: 2m 3s	remaining: 11m 42s
# 1600:	learn: 0.9395694	test: 0.9257959	best: 0.9258915 (1576)	total: 2m 13s	remaining: 11m 40s
# 1700:	learn: 0.9402386	test: 0.9259844	best: 0.9260804 (1645)	total: 2m 22s	remaining: 11m 37s
# 1800:	learn: 0.9409779	test: 0.9261774	best: 0.9262712 (1784)	total: 2m 34s	remaining: 11m 42s
# 1900:	learn: 0.9416712	test: 0.9264585	best: 0.9267439 (1858)	total: 2m 42s	remaining: 11m 34s
# 2000:	learn: 0.9425529	test: 0.9261701	best: 0.9267439 (1858)	total: 2m 52s	remaining: 11m 29s
# 2100:	learn: 0.9431976	test: 0.9265542	best: 0.9267439 (1858)	total: 3m 5s	remaining: 11m 35s
# 2200:	learn: 0.9441296	test: 0.9265555	best: 0.9267451 (2108)	total: 3m 17s	remaining: 11m 39s
# 2300:	learn: 0.9447964	test: 0.9272288	best: 0.9275143 (2272)	total: 3m 26s	remaining: 11m 31s
# 2400:	learn: 0.9453206	test: 0.9275150	best: 0.9277048 (2360)	total: 3m 39s	remaining: 11m 34s
# 2500:	learn: 0.9458937	test: 0.9280880	best: 0.9281811 (2494)	total: 3m 48s	remaining: 11m 25s
# 2600:	learn: 0.9463947	test: 0.9284702	best: 0.9284702 (2599)	total: 3m 57s	remaining: 11m 16s
# 2700:	learn: 0.9470906	test: 0.9288492	best: 0.9288492 (2682)	total: 4m 6s	remaining: 11m 6s
# 2800:	learn: 0.9476616	test: 0.9292328	best: 0.9292328 (2791)	total: 4m 15s	remaining: 10m 57s
# 2900:	learn: 0.9484044	test: 0.9292327	best: 0.9293285 (2882)	total: 4m 24s	remaining: 10m 46s
# 3000:	learn: 0.9490266	test: 0.9293298	best: 0.9294255 (2994)	total: 4m 32s	remaining: 10m 35s
# 3100:	learn: 0.9497429	test: 0.9296124	best: 0.9296124 (3096)	total: 4m 43s	remaining: 10m 30s
# 3200:	learn: 0.9503155	test: 0.9298054	best: 0.9299018 (3160)	total: 4m 52s	remaining: 10m 21s
# 3300:	learn: 0.9511048	test: 0.9301864	best: 0.9302849 (3288)	total: 5m 2s	remaining: 10m 13s
# 3400:	learn: 0.9517505	test: 0.9302840	best: 0.9303820 (3367)	total: 5m 13s	remaining: 10m 7s
# 3500:	learn: 0.9522518	test: 0.9302807	best: 0.9303820 (3367)	total: 5m 35s	remaining: 10m 23s
# 3600:	learn: 0.9528487	test: 0.9302809	best: 0.9303820 (3367)	total: 5m 45s	remaining: 10m 13s
# 3700:	learn: 0.9535412	test: 0.9302799	best: 0.9305684 (3683)	total: 5m 54s	remaining: 10m 2s
# 3800:	learn: 0.9544486	test: 0.9306615	best: 0.9308542 (3788)	total: 6m 3s	remaining: 9m 52s
# 3900:	learn: 0.9553562	test: 0.9308551	best: 0.9309498 (3875)	total: 6m 14s	remaining: 9m 45s
# 4000:	learn: 0.9558082	test: 0.9311416	best: 0.9311416 (3985)	total: 6m 23s	remaining: 9m 34s
# 4100:	learn: 0.9565719	test: 0.9311402	best: 0.9313313 (4063)	total: 6m 33s	remaining: 9m 25s
# 4200:	learn: 0.9572655	test: 0.9314293	best: 0.9314293 (4195)	total: 6m 42s	remaining: 9m 15s
# 4300:	learn: 0.9578381	test: 0.9318131	best: 0.9318131 (4272)	total: 6m 54s	remaining: 9m 8s
# 4400:	learn: 0.9586030	test: 0.9314291	best: 0.9319078 (4304)	total: 7m 2s	remaining: 8m 57s
# 4500:	learn: 0.9592234	test: 0.9316199	best: 0.9319078 (4304)	total: 7m 15s	remaining: 8m 51s
# 4600:	learn: 0.9597021	test: 0.9316173	best: 0.9319078 (4304)	total: 7m 28s	remaining: 8m 46s
# 4700:	learn: 0.9605125	test: 0.9318090	best: 0.9320943 (4661)	total: 7m 42s	remaining: 8m 41s
# 4800:	learn: 0.9610144	test: 0.9316191	best: 0.9320943 (4661)	total: 7m 52s	remaining: 8m 31s
# 4900:	learn: 0.9617554	test: 0.9316167	best: 0.9320943 (4661)	total: 8m 4s	remaining: 8m 23s
# 5000:	learn: 0.9622333	test: 0.9316185	best: 0.9320943 (4661)	total: 8m 16s	remaining: 8m 16s
# 5100:	learn: 0.9627816	test: 0.9312347	best: 0.9320943 (4661)	total: 8m 28s	remaining: 8m 8s
# bestTest = 0.93209434
# bestIteration = 4661
# Shrink model to first 4662 iterations.

# %% [markdown]
# ### Предсказания модели на валидационнвых данных и подсчет метрик

# %%
y_pred = model.predict(valid_pool)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#  Обязанности       0.83      0.78      0.80       440
#   Требования       0.84      0.70      0.77       228
#      Условия       0.74      0.86      0.79       359
#
#     accuracy                           0.79      1027
#    macro avg       0.80      0.78      0.79      1027
# weighted avg       0.80      0.79      0.79      1027

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#  Обязанности       0.91      0.95      0.93      4482
#   Требования       0.95      0.91      0.93      3441
#      Условия       0.94      0.93      0.93      2552
#
#     accuracy                           0.93     10475
#    macro avg       0.94      0.93      0.93     10475
# weighted avg       0.93      0.93      0.93     10475

# %% [markdown]
# ### Предсказания модели на всем датасете

# %%
# df = pd.read_parquet('/content/df')

# %%
# Разбиваем колонку "Описание" на предложения
df_test = split_to_sent(df_new, [df_new.columns[2]])
# Out:
# 6281

# %%
df_test['clean_text'] = raw_data.param.apply(clean_text)
df_test['index'] = df_test.index

# %%
df_test.head()
# Out:
#                                                param     class  \
# 0                  Работа на строительных площадках.  Описание
# 0                              Очистных сооружениях.  Описание
# 1  Гнутье арматурной стали на механических станка...  Описание
# 1              Сборка и установка сеток и плоских...  Описание
# 2                                    Вязка арматуры.  Описание
#
#                                           clean_text  index
# 0  выполнение работа гнутьё резка арматурный стат...      0
# 0  выполнение работа гнутьё резка арматурный стат...      0
# 1  опыт строительство приветствоваться работа бри...      1
# 1  опыт строительство приветствоваться работа бри...      1
# 2  опыт работа год наличие удостоверение документ...      2

# %%
# Выполняем предсказания
df_test['pred'] = df_test['clean_text'].apply(lambda x: ''.join(model.predict([x])))
df_test['index'] = df_test['index']

# %%
df_test.to_parquet('/home/user/Загрузки/train_dataset_Минстрой(1)/raw_data', compression='gzip')

# %%
# Функция для вывода вакансии
def make_final_file(df):
  duties = '\n'.join(df.loc[df['pred'] == 'Обязанности', 'param'].values.tolist())
  requirements = '\n'.join(df.loc[df['pred'] == 'Требования', 'param'].values.tolist())
  conditions = '\n'.join(df.loc[df['pred'] == 'Условия', 'param'].values.tolist())
  final_file = f'Обязанности:\n\n{duties}\n\nТребования:\n\n{requirements}\n\nУсловия\n\n{conditions}'
  return final_file

# %%
some_vacancy = df_test.loc[df_test['index'] == 5]

# %%
print(make_final_file(some_vacancy))
# Out:
# Обязанности:
#
# Требуется АРМАТУРЩИК на крупнейший завод по производству железобетонных конструкций 3-4 разряда!
# Обязанности: Вязка арматуры для заливки конструкции железобетонных изделий.
#
# Требования:
#
# Требования: Опыт работы от 1 года , наличие удостоверения (документы должны присутствовать + запись в трудовой книжке).
# Желание работать и зарабатывать Условия: Работа вахтой от 45/60/90/120 смен;
#
# Условия
#
# Ставка за смену 3080 руб при графике 6/1 по 11 часов.
# Предоставляем час обеда + перерывы 10-15 мин.
# Трудоустройство и заселение в общежитие в день обращения;
# Бесплатное проживание в комфортном общежитии (постельное бельё предоставляем);
# Питание 1 раз в день предоставляется на заводе В общежитии есть кухня и все необходимое для приготовления пищи;
# Работа в закрытом теплом цехе Удобный график работы ночь или день;
# -Вахта от 45 смен, зп на руки 138 600.
# Иногородним предоставляется проживание бесплатное в общежитии Объект расположен по адресу : гор. Подпорожье Ленинградская область.
# Рассматриваем кандидатов с опытом работы: арматурщик, строитель, разнорабочий. работа вахтой в Санкт-Петербурге, вакансия вахта, вахтовый метод, вахта прямой работодатель, работа вахтой без опыта, работа с проживанием прямой работодатель, работа вакансии, работа вахтой вакансии, разнорабочий, рабочий, сборщик, подсобный рабочий, работник завода,работа в москве и подмосковье вахтой.формовщик

# %% [markdown]
# ### Сохранение и загрузка модели

# %%
filename = '/home/user/Загрузки/train_dataset_Минстрой(1)/finalized_model.pickle'
# pickle.dump(model, open(filename, 'wb'))

# %%
with open(filename, 'rb') as f:
   model = pickle.load(f)

# %% [markdown]
# ### Создание итоговой таблицы

# %%
# Группируем в итоговую таблицу
def final_table(df):  # помещаем df c предсказаниями модели
  vacancy_table = df.groupby(['index', 'pred'],as_index=False)['param'].agg(lambda x: ' '.join(x))
  tab = pd.DataFrame()
  final_table = pd.DataFrame()
  for i in vacancy_table['index'].unique():
    for col in vacancy_table['pred'].unique():
      try:
        tab[col] = vacancy_table.loc[(vacancy_table['pred'] == col) & (vacancy_table['index'] == int(i)) , 'param'].values
      except:
        tab[''] = ''
    tab['index'] = int(i)
    final_table = pd.concat([final_table, tab], ignore_index=True)
  return df

# %%
final_table = final_table(df_test)

# %%
concat_df = df_new[['id', 'Название']]

# %%
stacked = pd.merge(concat_df, final_table, left_index=True, right_index=True)

# %%
stacked.drop('index', axis=1, inplace=True)

# %%
stacked
# Out:
#           id           Название  \
# 0    9495846         Арматурщик
# 1    9495850         Арматурщик
# 2    9495851         Арматурщик
# 3          2         Арматурщик
# 4    9388857         Арматурщик
# ..       ...                ...
# 994  9306889            Инженер
# 995  9306890          Монтажник
# 996  9306891  Слесарь-Ремонтник
# 997  9306892         Арматурщик
# 998  9306893  Слесарь-Ремонтник
#
#                                            Обязанности     \
# 0    Работа на строительных площадках. Очистных соо...
# 1    Гнутье арматурной стали на механических станка...
# 2                                      Вязка арматуры.
# 3    Выполнение работ по гнутью и резке арматурной ...
# 4    Обязанности: армирование каркаса; Питание трех...
# ..                                                 ... ..
# 994  Обязанности: Проектирование ультразвуковых пре...
# 995  Требуется монтажник вентиляции, возможно учени...
# 996  Требуется слесарь в цех по ремонту и балансиро...
# 997  К нам в команду требуются: . Мастер по оклейке...
# 998  К нам в команду требуются: . Мастер по оклейке...
#
#                                             Требования  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    Требования: опыт в строительстве приветствуетс...
# ..                                                 ...
# 994  ООО &quot;Ньювент-Уфа&quot; стаж работы желате...
# 995  Приветствуется опыт по установке систем кондиц...
# 996  Токарные навыки и сварочные навыки приветствую...
# 997  Мастер по оклейке автомобилей в цветные пленки...
# 998  Мастер по оклейке автомобилей в цветные пленки...
#
#                                                Условия
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    Вахта в город Москва. Условия: продолжительнос...
# ..                                                 ...
# 994  Требуются соискатели граждане РФ, с паспортом ...
# 995  Внимание пока обьявление висит, ведется набор!...
# 996               Зарплата, график работы обсуждаются.
# 997  Оплата высокая, сдельная, выплаты по факту вып...
# 998  Описание работодателя: Спичечная фабрика ФЭСКО...
#
# [999 rows x 6 columns]

# %%
# Сохранение в эксель
stacked.to_excel('/home/user/Загрузки/train_dataset_Минстрой(1)/output.xlsx', index=False)

# %% [markdown]
# ### Для наглядности используем gradio

# %% [markdown]
# Структурирование вакансии

# %%
# Разбивка текста на предложения
def split_to_sent_text(df):
    df_splited = pd.DataFrame()
    df_splited['text'] = df['text'].apply(lambda x: x.split('\n'))
    df_splited = df_splited.explode('text')
    df_splited = df_splited.replace(r'^\s*$', np.nan, regex=True)
    df_splited.dropna(inplace=True)
    return df_splited

# %%
# Преобразование текста в датафрейм
def text_to_df(text):
  df = pd.DataFrame()
  df['text'] = [text]
  return df

# %%
def make_final_vacancy(text):
  df = text_to_df(text)
  df_splited = split_to_sent_text(df)
  print('ok')
  df_splited['clean_text'] = df_splited['text'].apply(clean_text)
  df_splited['pred'] = df_splited['clean_text'].apply(lambda x: ''.join(model.predict([x])))
  duties = '\n'.join(df_splited.loc[df_splited['pred'] == 'Обязанности', 'text'].values.tolist())
  requirements = '\n'.join(df_splited.loc[df_splited['pred'] == 'Требования', 'text'].values.tolist())
  conditions = '\n'.join(df_splited.loc[df_splited['pred'] == 'Условия', 'text'].values.tolist())
  final_file = f'Обязанности:\n\n{duties}\n\nТребования:\n\n{requirements}\n\nУсловия\n\n{conditions}'
  return final_file

# %%
text = '''Планирование, организация и контроль работы подрядных организаций, выполняющих ремонтные работы;
Планирование, организация ремонтных работ;
Заключение договоров подряда, контроль выполнения;
Контроль корректности документов на выполненные работы и полученные материалы (КС-2, КС-3, акты, накладные, счета-фактуры);
Подготовка и контроль исполнения бюджета работ;
Взаимодействие с управляющими органами ТЦ по вопросам строительных работ;
Контроль соблюдения правил безопасности на объектах во время выполнения строительных работ;
Передача закрывающей и исполнительной документации после завершения работ в службы Заказчика.


Высшее/среднее профессиональное техническое образование;
Релевантный опыт работы от 2-х лет в крупных розничных сетях;
Координация и контроль работ по выполнению поставленных задач;
Опыт работы с подрядными организациями, проведение переговоров;
Уверенные знания по составу, наполнению и методики чтения проектной документации (стадий РД, ИД);
Уверенные знания в области инженерии, строительных работ, СНиП, ПТЭЭП, ПУЭ, ПБ, ЭБ, ОТ;
Готовность к командировкам.


Работу в комфортабельном и уютном офисе в БЦ Кунцево Плаза в 5 минутах пешком от м. Молодежная;
График работы 5/2, 9.30-18.30;
Оформление в соответствии с ТК РФ, официальную заработную плату (выплата 2 раза в месяц), оплачиваемый больничный лист, оплачиваемый отпуск 28 календарных дней;
ДМС включая стоматологию, корпоративного врача (условия в зависимости от стажа работы);
Дисконтную карту на продукцию компании, участие в распродажах в офисе;
Корпоративные скидки на фитнес;
Реальные перспективы профессионального и карьерного роста;
А еще уютные лаундж-зоны, технологичные переговорные, просторные кухни и вкусный капучино.'''

# %%
# create the Gradio interface
iface = gr.Interface(fn=make_final_vacancy, inputs=gr.inputs.Textbox(label="Text"), outputs="text")

# launch the Gradio interface
iface.launch()

# %%
def filter_rows(str1, str2):
    df = pd.read_excel('/home/user/Загрузки/train_dataset_Минстрой(1)/output.xlsx')
    mask = df["Условия"].str.lower().str.contains(str1) | df["Требования"].str.lower().str.contains(str1) | df["Условия"].str.lower().str.contains(str2) | df["Требования"].str.lower().str.contains(str2)
    result = df[mask]
    #result[["id", "Name"]]
    #return result.to_string(index=False)
    #return result[["id", "name"]]
    return result[['id', "Название", 'Обязанности']].to_string(index=False, header=False)
#     return result.columns[result.columns == "name"]

iface = gr.Interface(fn=filter_rows,
                     inputs=[gr.inputs.Textbox(label="Я хочу"),
                             gr.inputs.Textbox(label="У меня имеется")],
                     outputs=gr.outputs.Textbox(label="Результат"))

iface.launch()
